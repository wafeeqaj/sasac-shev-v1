# %% [markdown]
# # Paper figures

# %%
import sys
sys.path.insert(0, '..')
# %matplotlib inline
from sasac.utils.paper_figures import fig3, fig4, validation_table

# %% [markdown]
# ## Fig. 3: ablation studies

# %%
fig3('../results/runs', out='../figures/fig3_ablation.png');

# %% [markdown]
# ## Fig. 4: SOC trajectories

# %%
fig4('../results/validation', '../results/dp/plain', out='../figures/fig4_soc_trajectories.png');

# %% [markdown]
# ## Tables III / IV

# %%
validation_table('../results/validation', '../results/dp/plain')
